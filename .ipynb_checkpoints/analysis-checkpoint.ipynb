# %%
#!/usr/bin/env python3

import csv
import sys
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd

# %%
def read_position(file):
    x = []
    y = []
    z = []
    d = []
    reader = csv.reader(open(file))
    data = [row for row in reader]

    for row in data[1:]:
        if row[1] == '':
            continue
        x.append(float(row[1]))
        y.append(float(row[2]))
        z.append(float(row[3]))
        a = np.sqrt(float(row[1])**2 + float(row[2])**2 + float(row[3])**2)
        d.append(float(a))
    return x, y, z, d
        
def read_position_noZ(file):
    x = []
    y = []
    d = []
    reader = csv.reader(open(file))
    data = [row for row in reader]

    for row in data[1:]:
        if row[1] == '':
            continue
        x.append(float(row[1]))
        y.append(float(row[2]))
        a = np.sqrt(float(row[1])**2 + float(row[2])**2)
        d.append(float(a))
    return x, y, d

# %%
file1_paths = ['./csv_1/0_1.csv.converted.csv', 
              './csv_1/0_2.csv.converted.csv', 
              './csv_1/0_3.csv.converted.csv', 
             './csv_1/1_2.csv.converted.csv', 
             './csv_1/1_3.csv.converted.csv', 
             './csv_1/2_3.csv.converted.csv']

file2_paths = ['./csv_2/0_1.csv.converted.csv', 
              './csv_2/0_2.csv.converted.csv', 
              './csv_2/0_3.csv.converted.csv', 
             './csv_2/1_2.csv.converted.csv', 
             './csv_2/1_3.csv.converted.csv', 
             './csv_2/2_3.csv.converted.csv']

# %%
def graph1(file_path):
    
    x, y, z, d = read_position(file_path)


    # Plot
    fig, axes = plt.subplots(2, 2, figsize=(9, 7), dpi=90)
    print('--------------------')
    for ax, col, data, name in zip(axes.ravel(), 
                                        ['orange','r','b','g'], 
                                        [d,x,y,z], 
                                        ['D','X','Y','Z']):
        lmax = len(data)
        ax.set_title(name)
        ax.plot(data, '.', color=col)
        ax.hlines([np.mean(data)], 0, lmax, "black",label='mean')
        ax.legend()
        print(f"{name}",'[mean/ error/ std]=',
              '{:.03f}'.format(np.mean(data)), 
              '[m]/', '{:.05f}'.format(abs(max(data)) - np.mean(data)), 
              '[m]/', '{:.05f}'.format(np.std(data)),'[m]')

# %%
def output1(files):
    for file, tag in zip(files, ['0_1','0_2','0_3','1_2','1_3','2_3']):
        print(tag)
        output_graph(file)
        plt.show()

# %%
output1(file1_paths)
# Out:
# 0_1
# --------------------
# D [mean/ error/ std]= 5.025 [m]/ 0.43169 [m]/ 0.18761 [m]
# X [mean/ error/ std]= 4.777 [m]/ 0.56926 [m]/ 0.22139 [m]
# Y [mean/ error/ std]= 1.491 [m]/ 1.35052 [m]/ 0.19955 [m]
# Z [mean/ error/ std]= 0.201 [m]/ 0.81535 [m]/ 0.33829 [m]
# 0_2
# --------------------
# D [mean/ error/ std]= 10.144 [m]/ 0.58636 [m]/ 0.26303 [m]
# X [mean/ error/ std]= 9.751 [m]/ 0.67911 [m]/ 0.34734 [m]
# Y [mean/ error/ std]= 2.688 [m]/ 1.07710 [m]/ 0.33273 [m]
# Z [mean/ error/ std]= 0.022 [m]/ 1.61352 [m]/ 0.64801 [m]
# 0_3
# --------------------
# D [mean/ error/ std]= 15.226 [m]/ 0.78068 [m]/ 0.40007 [m]
# X [mean/ error/ std]= 14.456 [m]/ 1.10499 [m]/ 1.26492 [m]
# Y [mean/ error/ std]= 4.375 [m]/ 6.66571 [m]/ 0.81840 [m]
# Z [mean/ error/ std]= 0.226 [m]/ 7.13178 [m]/ 1.24441 [m]
# 1_2
# --------------------
# D [mean/ error/ std]= 5.143 [m]/ 0.47008 [m]/ 0.16026 [m]
# X [mean/ error/ std]= 4.989 [m]/ 0.43500 [m]/ 0.21679 [m]
# Y [mean/ error/ std]= 1.156 [m]/ 0.63351 [m]/ 0.28278 [m]
# Z [mean/ error/ std]= -0.165 [m]/ 0.86317 [m]/ 0.31237 [m]
# 1_3
# --------------------
# D [mean/ error/ std]= 10.149 [m]/ 1.87613 [m]/ 0.34685 [m]
# X [mean/ error/ std]= 9.610 [m]/ 1.09159 [m]/ 0.95041 [m]
# Y [mean/ error/ std]= 2.949 [m]/ 6.54211 [m]/ 0.65347 [m]
# Z [mean/ error/ std]= 0.084 [m]/ 7.19764 [m]/ 0.85593 [m]
# 2_3
# --------------------
# D [mean/ error/ std]= 5.261 [m]/ 12.11180 [m]/ 1.12413 [m]
# X [mean/ error/ std]= 4.719 [m]/ 1.02173 [m]/ 1.65977 [m]
# Y [mean/ error/ std]= 1.480 [m]/ 6.86547 [m]/ 1.01827 [m]
# Z [mean/ error/ std]= -0.029 [m]/ 7.69694 [m]/ 0.83007 [m]

# %%
def graph2(file_path):
    x, y, z, d = read_position(file_path)
    
    mean_x = np.mean(x)
    mean_y = np.mean(y)
    mean_z = np.mean(z)
    mean_d = np.mean(d)
    lmax = len(x)
    
    # Plot
    # fig, axes = plt.subplots(2, 2, figsize=(9, 7), dpi=90)
    
    for col, data, mean, name in zip(['orange','r','b','g'],
                                     [d,x,y,z],
                                     [mean_d,mean_x,mean_y,mean_z],
                                     ['D','x','y','z']):
        plt.plot(data-mean, '.', color=col, label=name)
        plt.legend()
        plt.hlines([0], 0, lmax, "black")
    plt.show()

def output2(files):
    for file, tag in zip(files, ['0_1','0_2','0_3','1_2','1_3','2_3']):
        print(tag)
        graph2(file)
        plt.show()

# %%
graph2(file2_paths[0])

# %%
output2(file2_paths)
# Out:
# 0_1
# 0_2
# 0_3
# 1_2
# 1_3
# 2_3

# %%
output2(file1_paths)
# Out:
# 0_1
# 0_2
# 0_3
# 1_2
# 1_3
# 2_3

# %%
def output_graph_noZ(file_path, ylim):
    x=[]
    y=[]
    d=[]
    
    
    mean_x = np.mean(x)
    mean_y = np.mean(y)
    mean_d = np.mean(d)
    
    # Plot
    fig, axes = plt.subplots(2, 2, figsize=(9, 7), dpi=90)
    
    for ax, col, data, mean, name in zip(axes.ravel(), 
                                        ['orange','r','b'], 
                                        [d,x,y],
                                        [mean_d,mean_x,mean_y],
                                        ['D*','X*','Y*']):
        lmax = len(data)
        ax.set_title(name)
        ax.set_ylim(-ylim, ylim)
        ax.axes.xaxis.set_visible(False)
        ax.plot(data-mean, '.', color=col)
        ax.hlines([0], 0, lmax, "black")

# %%
# graphs2_noZ(file2_paths,0.3)

# %%
fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)

for file, title, col, label in zip([file1_paths, file2_paths],
                                   ['Tag position Ex1', 'Tag position Ex2'],
                                   ['b','orange'],
                                   ['Ex1', 'Ex2']):
    
    x0_1, y0_1, d0_1 = read_position_noZ(file[0])
    x0_2, y0_2, d0_2 = read_position_noZ(file[1])
    x0_3, y0_3, d0_3 = read_position_noZ(file[2])

    mean_d = [np.mean(d0_1), np.mean(d0_2), np.mean(d0_3)]
    
    print(title)
    print('Distance(0-1)=', '{:.04f}'.format(mean_d[0]),'m')
    print('Distance(0-2)=', '{:.04f}'.format(mean_d[1]),'m')
    print('Distance(0-3)=', '{:.04f}'.format(mean_d[2]),'m')
    print('-------')

    x = x0_1 + x0_2 + x0_3
    y = y0_1 + y0_2 + y0_3
    
    
    ax.set_ylim(0, 6)
    ax.set_xlim(0, 16)
    ax.set_xlabel('x, East')
    ax.set_ylabel('y, North')
    plt.scatter(x, y, color=col,label=label)
    plt.legend()

plt.show()
# Out:
# Tag position Ex1
# Distance(0-1)= 5.0093 m
# Distance(0-2)= 10.1227 m
# Distance(0-3)= 15.1692 m
# -------
# Tag position Ex2
# Distance(0-1)= 4.8557 m
# Distance(0-2)= 9.7142 m
# Distance(0-3)= 14.6543 m
# -------

# %%
# EX1を絞る
# 1057-1065で大きくなる
# 1072-1162で小さくなる
def filter_ex1(file):
    x = []
    y = []
    z = []
    d = []
    reader = csv.reader(open(file))
    data = [row for row in reader]

    for row in data[1:1056]:
        if row[1] == '':
            continue
        x1.append(float(row[1]))
        # y.append(float(row[2]))
        # z.append(float(row[3]))
        # a = np.sqrt(float(row[1])**2 + float(row[2])**2 + float(row[3])**2)
        # d.append(float(a))
        
    for row in data[1057:1065]:
        if row[1] == '':
            continue
        x2.append(float(row[1]))
        # y.append(float(row[2]))
        # z.append(float(row[3]))
        # a = np.sqrt(float(row[1])**2 + float(row[2])**2 + float(row[3])**2)
        # d.append(float(a))
        
    for row in data[1066:1072]:
        if row[1] == '':
            continue
        x3.append(float(row[1]))
        # y.append(float(row[2]))
        # z.append(float(row[3]))
        # a = np.sqrt(float(row[1])**2 + float(row[2])**2 + float(row[3])**2)
        # d.append(float(a))
    
    for row in data[1:1056]:
        if row[1] == '':
            continue
        x.append(float(row[1]))
        # y.append(float(row[2]))
        # z.append(float(row[3]))
        # a = np.sqrt(float(row[1])**2 + float(row[2])**2 + float(row[3])**2)
        # d.append(float(a))
        
    return x

# %%
x1 = filter_ex1(file1_paths[0])
